# %% [markdown]
# #Self
# In python self is a fundamental concept when working with oops. It represents instance of a class being used.
# Whenever we create object form class sels refers to the current object. When we call a method or an object then self automatically gets passed to the method.
# self allows us to modify the internal state of an object

# %%
#self ex1
class Counter:
    def __init__(self):
        self.count = 0
    def increment(self):
        self.count+=1
    def decrement(self):
        self.count-=1
    def getcount(self):
        return self.count
c = Counter()
c.increment()
c.increment()
print(c.getcount())
# Out:
# 2

# %% [markdown]
# ## Types of variables in a class
# In Python OOPs , variables inside a class are mainly classified based on where they are created and how they are shared.
# There are many types:
# 1. Instance variable
# 2. Class Variable
# 3. Local Variable
# ### Instance Variable
# These are variable who have separate copy , created for every object. They belong to individual object not the class.

# %%
#Instance ex:
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

s1 =Student("Deepika",30)
s2 =Student("Radha",22)
print(s1.name)
print(s2.name)
s1.name="diya"
print(s1.name)
# Out:
# Deepika
# Radha
# diya

# %% [markdown]
# ### Instance characteristics
# * we can access instance variable within the class by using self, and outside the class by using reference variable .
# * Their values differ from object to object.
# * they are stored in object memory
#
#
# we can create Instance variable inside constuctor or inside functions.

# %%
#inside function instance
class Student:
    def set(self,name,age):
        self.name=name
        self.age = age
s1=Student()
s2=Student()
s1.set("Diya",21)
print(s1.name)
# Out:
# Diya

# %% [markdown]
# we can create instance variable outside the class also

# %%
class Student:
    pass

s1=Student()
s1.name="Diya"
print(s1.name)
# Out:
# Diya

# %% [markdown]
# ### Class Variables
# These are variables shared by all object of a class.
# Only one copy exist for entire class.
# They are declared inside the class but outside the method, they are accessed using class name

# %%
#Class variable example
class Student:
    college="IIT Delhi"
    def __init__(self,name):
        self.name=name

s1=Student("Deepika")
s2=Student("Virat")

print(s1.name, s1.college)
print(s2.name, s2.college)
#After changing class variable college value
Student.college="Sait"
print(s1.name, s1.college)
print(s2.name, s2.college)
# Out:
# Deepika IIT Delhi
# Virat IIT Delhi
# Deepika Sait
# Virat Sait

# %% [markdown]
# ####  \_\_dict\_\_
# it represents instance variable of an object as dictionary(key and value pairs)

# %%
class Student:
    college="IIT Delhi"
    def __init__(self,name,city):
        self.name=name
        self.city=city
        
s1=Student("Deepika","chennai")
s2=Student("Virat","Delhi")

print(s1.__dict__)
print(s2.__dict__)
#changing college of s1 object, here when changing objects class variable it creates a instance copy variable
s1.college="sait"

print(s1.__dict__)
print(s2.__dict__)

# %%
class Test:
    x = 10
t1=Test()
t2=Test()
t1.x=90
print(t1.x)
print(t2.x)
print(t1.__dict__)
Test.x=100
print(t1.x)
print(t2.x)
Test.y=900
print(t1.y)
print(t2.y)
# Out:
# 90
# 10
# {'x': 90}
# 90
# 100
# 900
# 900

# %%
class Test:
    def __init__(self):
        self.a=10
        self.b=20
    def m1(self):
        self.c=30
        self.d=40
t1=Test()
t1.m1()
t1.e=900
print(t1.__dict__)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 900}

# %%
class Test:
    a = 10
    def __init__(self):
        self.b=20
        Test.c=50
    def m1(self):
        Test.c=100
t1=Test()
t1.m1()
t2 = Test()
print(t1.__dict__)
print(t2.a)
print(t2.b)
print(t2.c)
print(Test.__dict__)
# Out:
# {'b': 20}
# 10
# 20
# 50
# {'__module__': '__main__', '__firstlineno__': 1, 'a': 10, '__init__': <function Test.__init__ at 0x0000015977E43E20>, 'm1': <function Test.m1 at 0x0000015977E42340>, '__static_attributes__': ('b',), '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'c': 50}

# %% [markdown]
# ### Local variable
# its a variable that is local and doesn't belong to any class and instance ,

# %%
class Test:
    def __init__(self,a,b):
        self.a=a
        self.b=b
        c=self.a+self.b
        print(c)
t1 = Test(10,20)
# Out:
# 30

# %%
class Test:
    a=10
    def __init__(self):
        print(self.a)
t1=Test()
print(t1.__dict__)
# Out:
# 10
# {}

# %% [markdown]
# ###H.W.
# #### Difference between Instance variables and class variables
#
# #### Python Synchronous or Asynchrounous

# %% [markdown]
# ### How to remove instance variable from object

# %%
class Test:
    def __init__(self):
        self.a=10
        self.b=20
        self.c=30
t1=Test()
t2=Test()
del t1.c
del t2.b
print(t1.__dict__)
print(t2.__dict__)
# Out:
# {'a': 10, 'b': 20}
# {'a': 10, 'c': 30}

# %% [markdown]
# ### Types of Methods in Python
# Python provides 3 types of methods:
# 1. Instance method
# 2. Class method
# 3. Static method
# #### 1. Instance Method
# It works with object. It can modify or access object data . It uses self parameter , its called using object. Examples we have done above.
# ##### Types of Instance Method:
# 1. Accessor method(getter): It is used to read data.
#     ```python
#     def get_marks(self):
#             return self.marks
#     ```
# 2. Mutator method(setter):used to modify data.
#    ```python
#     def set_marks(self):
#             self.marks=marks
#     ```
# #### 2. Class Method
# It works with class variables instead of instance variables. It affects the whole class, it is useful when we have to change class variable. It uses cls parameter, they are decorated with @classmethod.They are called using class name.
# ```python
# class Student:
#     college="NIT"
#     def __init__(self,name):
#         self.name=name
#
#     @classmethod
#     def change_college(cls,new):
#         cls.college=new
# s1=Student("deepika")
# print(s1.name)
# print(s1.college)
# Student.change_college("Sait")
# print(s1.college)
# ```
# Cls:
# Cls represents the class itself, it refers to current class. It gets automatically passed as a first parameter to a class method any other name is also possible.
# @classmethod is a decorator used to define class method. It belongs to class not object. It can access class variables , it can modify class state.
# #### 3. Static method
# Static method belong to class and doesn't access class data. It works like a normal function but placed inside a class for organisation.
# Here **staticmethod** decorator is used. A static method is a utility function inside a class that doesn't depend on object or class data.
# We can call static method either by using class name or by using object name.

# %%
#Class method example
class Student:
    college="NIT"
    def __init__(self,name):
        self.name=name

    @classmethod
    def change_college(cls,new):
        cls.college=new
s1=Student("deepika")
print(s1.name)
print(s1.college)
Student.change_college("Sait")
print(s1.college)
# Out:
# deepika
# NIT
# Sait

# %%
#Static method example
class Calculator:
    @staticmethod
    def add(a,b):
        return a+b
c1=Calculator()
print(c1.add(10,20))
print(Calculator.add(10,20))
print(c1.__dict__)
print(Calculator.__dict__)
# Out:
# 30
# 30
# {}
# {'__module__': '__main__', '__firstlineno__': 2, 'add': <staticmethod(<function Calculator.add at 0x000001EC70767A60>)>, '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'Calculator' objects>, '__weakref__': <attribute '__weakref__' of 'Calculator' objects>, '__doc__': None}

# %%
#Static but error here bcoz here a is class variable and should be accessed as Demo.a
# we cannot pass self or cls inside a static method
class Demo:
    a=10
    @staticmethod
    def display():
        print(a)
c1=Demo()
c1.display()

# %%
class Student:
    college="IIT"
    def set(self,name):
        self.name=name
    @staticmethod
    def display(x):
        print(Student.college)
        #print(name) #we cannot access directly
        #print(self.name) # we cant access with self as self is not passed , we do send a object as a parameter to a object to do it
        print(x.name)
c1 = Student()
c1.set("deepika")
c1.display(c1)
# Out:
# IIT
# deepika

# %% [markdown]
# ### Dynamic nature of a class
# Python classes are dynamic by nature , unlike many other languages where classes are fixed one's defined . Python classes are objects, it means we can add or remove attributes at run time , methods at run time

# %%
class Myclass:
    x=10
print(type(Myclass))
# Out:
# <class 'type'>

# %%
class Student: 
    name = "Deepika"
Student.age=30
s1=Student()
print(s1.name)
del Student.age##age will be deleted
del s1 ## we can delete objects directly
# Out:
# Deepika
# 30

# %% [markdown]
# #### Method Chaining
# It's a concept when one method of a class calls another method of the same class. There are 2 patterns for this
# 1. Internal Method Call: calling another instance method internally using self.
# 2. Method chaining using returning self: In example every method return self which allows next method to be called in the same line , with the help of this we can call multiple methods in a single line

# %%
#Internal method call 
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def displayname(self):
        print("Name is", self.name)
    def displaymarks(self):
        print("Marks",self.marks)
    def displayall(self):
        self.displayname()
        self.displaymarks()
s1 = Student("deepika",90)
s1.displayall()
# Out:
# Name is deepika
# Marks 90

# %%
#Returning self
class Student:
    def __init__(self,name):
        self.name=name
        self.marks=0
    def set_marks(self,marks):
        self.marks=marks
        return self
    def hello(self):
        print(f'Heyy {self.name}')
        return self
    def display(self):
        print(f'Your marks are : {self.marks}')
        #return self ## if we have to chain more methods
s1 = Student("deepika")
s1.hello().set_marks(80).display()
# Out:
# Heyy deepika
# Your marks are : 80

# %% [markdown]
# # Encapsulation
# Encapsulation is a binding of data with instance members .
# Encapsulation means wrapping data and functions inside a single unit called class.
# It is the process of binding data members and member functions together inside a class and control there access using access specifiers.
# With the help of encapsulation we can achieve data security.
# ### Access Specifiers:
# These define how class members can be accessed from outside the class.
# Types:
# #### 1. Public
# Public members are accessed from anywhere , by default all members in python are public.
# #### 2. Protected
# Protected members are variable or methods, which are accessed within the class or subclass. In Python protected members are defined using **single underscore**(self._name)
# #### 3. Private
# Private Members can not be accessed directly from outside the class. They are used to restrict the data. Defined using **double underscore** (self.__salary)

# %%
# Protected
class Student:
    def __init__(self,name):
        self._name=name
s1=Student("deepika")
print(s1._name) # we can access using _ . As python doesn't have any restriction on protected members
# Out:
# deepika

# %%
# Private
class Student:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary
s1=Student("deepika",500000)
print(s1.name)
#print(s1.__salary) ## Give error as salary is private
# Out:
# deepika

# %%
# Setter & Getter method
class Student:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary
    def get_salary(self):
        return self.__salary
    def set_salary(self,salary):
        self.__salary=salary
s1=Student("Deepika",50000)
print(s1.name)
print(s1.get_salary())
s1.set_salary(10)
print(s1.get_salary())
# Out:
# Deepika
# 50000
# 10

# %%
#Wap to create employee class which have id name and salary which are properly encapsulated  Constraints : 1. Name should not be empty , salary should be greater than 1000
class Employee:
    def __init__(self,id,name,salary):
        self.__id=id
        self.__name=name
        self.__salary= salary
    def get_id(self):
        return self.__id
    def set_id(self,id1):
        self.__id=id1
    def get_name(self):
        return self.__name
    def set_name(self,name1):
        if name1.strip()!="":
            self.__name=name1
        else:
            print("name cannot be empty")
    def get_salary(self):
        return self.__salary
    def set_salary(self,sal2):
        if sal2>1000:
            self.__salary=sal2
        else:
            print("salary should be more than 1000")

s1 = Employee(101,"deepika",50000)
print(s1.get_id())
print(s1.get_name())
print(s1.get_salary())
s1.set_id(102)
s1.set_name("")
s1.set_salary(500)
# Out:
# 101
# deepika
# 50000
# name cannot be empty
# salary should be more than 1000

# %% [markdown]
# #### Name mangling
# It is a  mechanism in python where private variables are internally renamed by python to avoid accidental access. It does not hide variable, instead it changes name internall.
# Mainling occurs when variable name starts with __ and doesnt end with __ . Ex: __init__,__len__ for these mangling will not work.
# __variablename
# convert to
# _classname__variablename

# %%
class Student:
    def __init__(self):
        self.__salary=100000
s1=Student()
#print(s1.__salary) # it gives error 
print(s1._Student__salary) # Name mangling converts salary to this and thus oop in python is not that efficient
# Out:
# 100000

# %%
class Bank_Balance:
    def __init__(self,bal):
        self.__bal = bal
    def deposit(self,bal):
        print("Deposit Successful")
        self.__bal = self.__bal+bal
    def withdraw(self,amt):
        if self.__bal>amt:
            print("withdraw successfull")
            self.__bal=self.__bal-amt
        else:
            print("Not enough Balance")
    def get_bal(self):
        return self.__bal
b1 = Bank_Balance(50)
b1.deposit(500)
print(b1.get_bal())
b1.withdraw(5000)
b1.withdraw(400)
print(b1.get_bal())
# Out:
# Deposit Successful
# 550
# Not enough Balance
# withdraw successfull
# 150

# %% [markdown]
# ##### Property Decorator
# A property is a special built-in feature in python that allows methods to be accessed like attributes. It helps to protect private data and keep clean syntax. Python provides built-in property function and @property is just a decorator version of it.  @property is most imp as without it , setter and deleter will not work

# %%
#Property example for getter
class Employee:
    def __init__(self,salary):
        self.__salary = salary
    @property
    def salary(self):
        return self.__salary
emp=Employee(1000000)
print(emp.salary)
# Out:
# 1000000

# %% [markdown]
# When we call emp.salary , python automatically calls salary but without parenthesis ().

# %%
#Property example for setter
class Employee:
    def __init__(self,sal):
        self.__salary=sal
    
    @property
    def salary(self):
        return self.__salary
    @salary.setter
    def salary(self,sal):
        self.__salary=sal
emp=Employee(50426)
print(emp.salary)
emp.salary=55555
print(emp.salary)
#Note: After this property object named salay will be created . 
# when we write @salary.setter , it says attach this functions as a setter function for the existing property named salary.
# Out:
# 50426
# 55555

# %%
# Wap to create student class with roll no , name and marks
class Student:
    def __init__(self, roll_no,name,marks):
        self.__roll_no = roll_no
        self.__name = name
        self.__marks = marks
    
    @property
    def roll_no(self):
        return self.__roll_no
    @roll_no.setter
    def roll_no(self,roll_no):
        self.__roll_no=roll_no
    @property
    def name(self):
        return self.__name
    @name.setter
    def name(self,name):
        self.__name=name
    @property
    def marks(self):
        return self.__marks
    @marks.setter
    def marks(self,marks):
        self.__marks=marks
    

c1=Student(101,"Deepika",40)
print(c1.roll_no)
c1.roll_no=55
print(c1.roll_no)
print(c1.name)
c1.name="Ram"
print(c1.name)
c1.marks=54
print(c1.marks)
# Out:
# 101
# 55
# Deepika
# Ram
# 54

# %%
#product id , title , price
class Product:
    def __init__(self,id,title,price):
        self.__id=id
        self.__title=title
        self.__price=price
    @property
    def id(self):
        return self.__id
    @property
    def title(self):
        return self.__title
    @title.setter
    def title(self,title):
        self.__title=title
    @property
    def price(self):
        return self.__price
    @price.setter
    def price(self,price):
        self.__price=price
p = Product(105,"Hp",55664)
print(p.id)
print(p.title)
p.title="victus"
print(p.title)
print(p.price)
p.price=66000   
print(p.price)
# Out:
# 105
# Hp
# victus
# 55664
# 66000

# %% [markdown]
# @property.deleter: It defines the method that runs automatically when we delete a property using **del obj.propertyname**

# %%
class Student:
    def __init__(self, roll_no,name,marks):
        self.__roll_no = roll_no
        self.__name = name
        self.__marks = marks
    
    @property
    def roll_no(self):
        return self.__roll_no
    @roll_no.setter
    def roll_no(self,roll_no):
        self.__roll_no=roll_no
    @property
    def name(self):
        return self.__name
    @name.setter
    def name(self,name):
        self.__name=name
    @name.deleter
    def name(self):
        del self.__name
    @property
    def marks(self):
        return self.__marks
    @marks.setter
    def marks(self,marks):
        self.__marks=marks
    @marks.deleter
    def marks(self):
        del self.__marks

s1 = Student(101,"Deepika",55)
print(s1.roll_no)
print(s1.name)
del s1.name
# print(s1.name) # give error as its already deleted
print(s1.marks)
del s1.marks #delete marks
# Out:
# 101
# Deepika
# 55

# %%
class Book:
    def __init__(self,no,title,author):
        self.__no=no
        self.__title=title
        self.__author=author
    @property
    def no(self):
        return self.__no
    @property
    def title(self):
        return self.__title     
    @property
    def author(self):
        return self.__author
    @title.setter
    def title(self,title):
        self.__title=title
    @author.setter
    def author(self,aut):
        self.__author=aut
    @title.deleter
    def title(self):
        del self.__title
    @author.deleter
    def author(self):
        del self.__author
b = Book(1,"White nights","Dostoevesky")
print(b.no)
print(b.title)
print(b.author)
b.title="Sangram"
print(b.title)
del b.title
b.author="Harivansh rai bachan"
print(b.author)
del b.author
# Out:
# 1
# Dostoevesky
# Sangram
# Harivansh rai bachan

# %%
# Area of triangle
class Triangle:
    def __init__(self,base,height):
        self.base = base
        self.height = height
    @property
    def area(self):
        return 1/2*(self.height*self.base)
c = Triangle(10,5)
c.area
# Out:
# 25.0

# %% [markdown]
# Property object stores four references:
# 1. fget--getter
# 2. fset--setter
# 3. fdel--deleter
# 4. doc--documentation string
